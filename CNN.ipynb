# %% [markdown]
# # CNN (CONVOLUTIONAL NEURAL NETWORK)

# %% [markdown]
# ## A Convolutional Neural Network (CNN) is a type of Deep Learning model that is specially designed to understand images.

# %% [markdown]
# ## Instead of looking at the entire image at once, CNN looks at small parts of the image, learns simple features first, and gradually combines them to recognize complex objects.

# %% [markdown]
# ### A CNN (convolutional neural network) is a neural network built specifically for grid-like data — mainly images. Instead of treating every pixel as an independent input like a plain ANN does, it uses small filters (kernels) that slide across the image and pick up local patterns — edges, textures, curves — then stack those patterns into more complex shapes as you go deeper.

# %% [markdown]
# ## WHAT IS KERNELS ?

# %% [markdown]
# ## A kernel (also called a filter) is a small matrix of numbers — usually 3×3 or 5×5 — that slides across the image and does one simple operation at each position: element-wise multiply, then sum.

# %% [markdown]
# ### THIS SINGLE NUMBER BECOME'S THE OUPUT FOR THE FEATURE MAP

# %% [markdown]
# ### ---KERNEL IS A 3 * 3 OR 5 * 5  MATRIX WHICH CONSITS OF SOME NUMBERS , IT STARTS FROM ONE PLACE OF THE IMAGE AND SLIDES(MOVE) ACROSS THE ALL POSITION OF THE IMAGE , AT EACH POSITION IT MULTIPLE'S WITH THE NUMBER PRESENT IN IMAGE AND SUMS IT UP AS **X** THIS SINGLE **X** IS THE OUTPUT OF SINGLE FRAME OF THE OUTPUT

# %% [markdown]
# ### --MORE WITH OPERATION DONE BY THE KERNEL ---> ELEMENT WISE MULTIPLICATION, THE FIRST ROW IS MULTIPLIED WITH FIRST ROW LIKE WISE IT GETS MULTIPLIED AND GETS SUMMED LATER (NOT MATRIX MULTIPLICATION)

# %% [markdown]
# ### WHAT IS STRIDE ?

# %% [markdown]
# ### ---NO OF PIXELS A FILTER/KERNEL AFTER EACH CONVOLUTION OPERATION

# %% [markdown]
# ### ---STEP SIZE OF THE JUMP AFTER EACH OPERATION

# %% [markdown]
# ### WHAT IS PADDING ?

# %% [markdown]
# ### Padding is the process of adding extra pixels (usually zeros) around the border of an input image before applying the convolution operation.

# %% [markdown]
# ### AS THE IMAGE SHRINKS AFTER THE CONVOLUTION OPERATION , WE MIGTH LOSS SOME IMPORTANT INFO AT THE OUTER PART OF IMAGE SO INORDER TO SORT IT OF , WE USE PADDING

# %% [markdown]
# # DETAILED EXPLANATION OF CNN

# %% [markdown]
# ### WHAT IS AN IMAGE ?

# %% [markdown]
# ### --IF WE BREAKDOWN THE IMAGE , IT IS NOTHING BUT A MATRIX WITH  SET OF NUMBERS WHICH RANGES FROM 0-255 WHICH DENOTES THE INTENSITY OF THE RESPECTIVE COLOUR AT EACH PIXEL

# %% [markdown]
# ### THERE CAN BE MANY KERNELS AS POSSIBLE , IT IS AN HYPERPARAMETER

# %% [markdown]
# ## WHAT IS CONVOLUTION OPERATION ?

# %% [markdown]
# ### ---THE KERNEL START'S WITH ONE POSTION IN A IMAGE AND IN THAT POSITION , IT MULTIPLIES ITS ROWS WITH THE ROWS OF THE IMAGES AND ADD'S IT UP IN EACH POSTION , THIS IS KNOW AS CONVOLUTION OPERATION

# %% [markdown]
# ### --MORE WITH OPERATION DONE BY THE KERNEL ---> ELEMENT WISE MULTIPLICATION, THE FIRST ROW IS MULTIPLIED WITH FIRST ROW LIKE WISE IT GETS MULTIPLIED AND GETS SUMMED LATER (NOT AS MATRIX MULTIPLICATION)

# %% [markdown]
# ### STRIDE --> THE BIG THE JUMP IS FROM ONE POSITION TO ANOTHER POSITION

# %% [markdown]
# ### ALGO

# %% [markdown]
# ### NOW THE KERNEL EITHER 3 * 3 OR 5 * 5 STARTS WITH ONE SIDE OF THE IMAGE , FIRTS AND DOES THE CONVOLUTION OPERATION AND GETS THE OUTPUT

# %% [markdown]
# ### THIS SINGLE OUPUT IS THE BECOMES THE VALUE OF THE ONE PIXEL IN THE OUTPUT FEATURE MAP

# %% [markdown]
# ### LIKE WISE THE KERNEL GET'S SLIDED (MOVED) THROUGTH THE IMAGE AND FINDS THE VALUE OF EACH SINGLE PIXEL

# %% [markdown]
# ### LIKE WISE THE NEXT KERNEL IS ACTVATED AND DOES THE SAME PROCESS

# %% [markdown]
# ### THEREFORE FOR **N** KERNELS WE GET **N** OUTPUT FEATURE MAP(The Output in a matrix form which we get after the row wise multiplication and the sum of kernel's)

# %% [markdown]
# ### OUTPUT OF THE CONVOLUTION OPERATION IS KNOW AS **FEATURE MAP**

# %% [markdown]
# ## **DEEP IN CONVOLUTION OPERATION -----> MUST READ IT**

# %% [markdown]
# ### IF THE INPUT IS RGB IMAGE , IT HAVE THREE CHANNELS (LIKE THE SET OF MATRIX(0-255) FOR EACH RED ,GREEN AND BLUE)

# %% [markdown]
# ### SOO THE CONVOLUTION OPERTAION TAKES PLACE LIKE IT

# %% [markdown]
# ### FOR EACH FILTER IN A POSITION FIRST WE CHOOSE , ONE CHANNELS LETS TAKE FROM RED , WE DO ELEMENT WISE MULTIPLICATION AND SUM IT UP AS WE KEEP AS A ONE VALUE LET IT BE **X**

# %% [markdown]
# ### THEN WE DO FOR BLUE AND GREEN THOSE CONVOLUTIONAL OPERTAION

# %% [markdown]
# ### THEN AGAIN WE SUM UP THE VALUES , AT THE POSITION (1,1) WE DO HAVE THREE DIFFRENT CONVOLUTION OPERTAION VALUES (RED,GREEN,BLUE) AND AGAIN WE SUM IT UP INTO ONE VALUE , SOO THIS FINAL VALUE WILL BE THE SINGLE PIXEL VALUE IN THE FEATURE MAP

# %% [markdown]
# ## ACTIVATION FUNCTION

# %% [markdown]
# ### THE ACTIVATION FUCNTION'S ARE SAME AS IN **ANN**

# %% [markdown]
# ### AFTER WE GET THE FEATURE MAP FROM THE CONVOLUTIONAL OPERATION , WE USE THE ACTIVATION FUNCTION

# %% [markdown]
# ### WE USE THE ACTIVATION FUNCTION FOR THE INTRODUCE THE NON-LINEARITY INTO THE NETWORK

# %% [markdown]
# ### WHY DO WE INTRODUCE NON-LINEARITY ?

# %% [markdown]
# ### --BECAUSE NO DATA IN THE REAL WORLD IS LINEAR , SO WITHOUT ACTIVATION FUNCTION (INTRODUCING THE NON-LINEARITY) NO MODEL CAN LEARN THE ACTUALL PATTTERN EFFICENTLY

# %% [markdown]
# ### THE PROCESS TILL NOW ----> INPUT IMAGE ---->CONVOLUTION OPERATION ---->FEATURE MAP ---->ACTIVATION FUNCTION(IN THE FEATURE MAP)

# %% [markdown]
# ## POOLING

# %% [markdown]
# ### IT IS A DOWNSAMPLING TECHINUE WHICH IS APPLIED AFTER THE ACTIVATION FUNCTION IN A FEATURE MAP

# %% [markdown]
# ### --IT IS USED FOR DIMENSION REDUCTION(Meanwhile we can reduce the computational power) WHILE RETAINING THE MOST IMPORTANT INFORMATION,  CONTROLS OVERFITTING ALSO EXTRACT THE DOMINANT FEATURES

# %% [markdown]
# ### Pooling is a downsampling operation applied to the feature map after activation, which reduces its spatial dimensions (height & width) while retaining the most important information, in order to reduce computation, control overfitting, and make the learned features more robust to small translations in the input.

# %% [markdown]
# ### WHAT IS WINDOW HERE ?

# %% [markdown]
# ### SAME AS KERNEL IN CONVOLUTIONAL BUT HERE WE DO NOT MULTIPLE ANYTHING WE JUST COMPARE

# %% [markdown]
# ## ALGO

# %% [markdown]
# ### FIRST START FROM THE RIGTH MOST PART FROM THE INPUT IMAGE PLACE THE WINDOW COMPARE , IF YOU DO MAX POOLING CHOOSE THE MAX ELEMENT FROM THE WINDOW ELSE IF YOU USE THE AVERAGE POOOLING AVERAGE IT TAKE THE OUPUT , THIS SINGLE OUTPUT BECOME THE VALUE OF THE SINGLE PIXEL OF THE OUTPUT POOLED FEATURE MAP

# %% [markdown]
# ### THEN MOVE YOUR WINDOW  ACCORDING TO TEH STRIDE WE HAVE MENTIONED

# %% [markdown]
# ### THEN DO THE SAME PROCESS AND FIND THE OUPUT AT EACH POSSIBLE PIXEL

# %% [markdown]
# ### IF THE INPUT IMAGE --> N*N px , POOLING WINDOW ---> F * F px, STRIDE ---> S

# %% [markdown]
# ### THE OUTPUT IMAGE WILL BE ---> (((N-F)/S)+1) * (((N-F)/S)+1) px

# %% [markdown]
# ### THE OUTPUT IMAGE WILL GET SHRINKED

# %% [markdown]
# ## WHAT IS MAX POOLING ?

# %% [markdown]
# ### IT IS A POOLING OPERTAION ,WHERE IN EACH WINDOW WE CHOOSE THE MAXIMUM VALUE AS THE OUTPUT

# %% [markdown]
# ### Max pooling is a operation where, for each window position on the feature map, you take the maximum value inside that window and discard the rest — keeping only the strongest activation from each region.

# %% [markdown]
# ##  WHAT IS AVERAGE POOLING ?

# %% [markdown]
# ### IN EVERY WINDOW WE CHOOSE THE OUTPUT AS THE **AVERAGE OF THE ELEMENTS** PRESENT INSIDE THE WINDOW

# %% [markdown]
# ### AVERAGE POOLING is a pooling operation where, for each window position on the feature map, you take the average (mean) of all values inside that window instead of the max.

# %% [markdown]
# ## AVERAGE VS MAX POOLING

# %% [markdown]
# ### USE MAX POOLING IN HIDDEN LAYERS

# %% [markdown]
# ### USE AVG POLLING IN FINAL LAYER BEFORE OUTPUT

# %% [markdown]
# ### MAX POOLING--> PICKS THE SRONGEST VALUES, PICKS THE NOISE

# %% [markdown]
# ### AVG POOLING --> PICKS THE AVERAGE VALUE, SMOOTHS THE NOISE

# %% [markdown]
# ## GLOBAL AVERAGE POOLING

# %% [markdown]
# ### AFTER THE PROESS OF POOLING WE GET **N** POOLED FEATURED MAP

# %% [markdown]
# ### WE CONVERT THE EACH SINGLE MAP INTO A NUMERICAL VALUE (MEAN VALUE) AVERAGE VALUE

# %% [markdown]
# ### SOO THE **N** MAPS ARE CONVERTED INTO **N** NUMERICAL VALUES AND STORED INTO A VECTOR

# %% [markdown]
# ### THIS PROCESS IS KNOW AS GLOBAL AVERAGE POOLING

# %% [markdown]
# ## FULLY CONNECTED LAYER(FC LAYER)

# %% [markdown]
# ### THIS IS THE LAYER IN WHICH THE INPUT VALUE IS CONNECTED TO AMD OUPTUT LAYER

# %% [markdown]
# ### FROM GAP WE DO GET **N** VALUES IN A FORM OF A SINGLE VECTOR

# %% [markdown]
# ### NOW WE MULTIPLE THE WIEGTH WITH EACH ELEMENT IN THE OUTPUT OF THE GAP VECTOR AND FINALLY ADD THE BIAS AND THAT IS OUPUT_1 LIKE WISE WE DO **C** TIMES FOR C_OUPUTS WITH **C** DIFFRENT WEIGTHS

# %% [markdown]
# ### OUTPUT_1= (VAL1*W1 + VAL2 *W1 + .... +VALN * W1) + BIAS

# %% [markdown]
# ### LIKE WISE : OUTPUT_C= (VAL1*WC + VAL2 *WC + .... +VALN * WC) + BIAS

# %% [markdown]
# ### NO OF OUPUT ARE FIXED ACCORDING TO THE LAYER

# %% [markdown]
# ### THEN HERE FOR **N** VALUES FROM THE VECTOR OF GAP, WE GET **C** OUTPUT

# %% [markdown]
# ## SOFT MAX

# %% [markdown]
# ### HERE IT TAKES THE OUTPUT FROM THE FULLY CONNECTED LAYER

# %% [markdown]
# ### IT CONVERTS THE OUPUT INTO THE RANGE OF 0-1 WHERE THE SUM OF CONVERTED C OUTPUTS WILL BE EQUAL TO EXACTLY 1

# %% [markdown]
# ### IT DOESNT CHANGE THE COUNT OF THE OUTPUT , IT TAKES C INPUTS AND GIVES C OUTPUTS

# %% [markdown]
# ### IT JUST CONVERYS INTO THE RANGE OF 0-1 AND WHERE THE SUM IS EXACLTY ==1

# %% [markdown]
# ## LOSS FUNCTION

# %% [markdown]
# ### A loss function is a mathematical function that measures the difference between the model's PREDICTED output and the ACTUAL/TRUE label, producing a single number that represents "how wrong" the prediction was — this number is what backprop uses to compute gradients and update weights.

# %% [markdown]
# ### IT TAKE THE OUTPUT FORM THE SOFTMAX AND COMPARES WITH THE ACTUALL VALUE AND GIVES THE OUPUT AS A SINLGE VALUE WHICH DESCRIBES HOW WRONG IS OUR MODEL IS COMPARED TO ACTUALL VALUE

# %% [markdown]
# ### **C** OUPUTS ARE TAKEN AND APLLIED TO A LOSS FUNCTION AND GETS A SINGLE VALUE WHICH DESCRIBES HOW BAD IS OUR MODEL IS

# %% [markdown]
# ### USUALLY THE VALUES CLOSER TO 0 IS ACCEPTABLE

# %% [markdown]
# ## BACKPROPOGATION

# %% [markdown]
# ### AFTER FINDING THE LOSS

# %% [markdown]
# ### IT COMPUTES THE GRADIENT OF THE LOSS

# %% [markdown]
# ### AND GOES BACK TO THE CONVOLUTIONAL OPERATION AND UPDATES THE WEIGTHS ACCCORNDING TO THE GRADIENT AND GO WITH POOLING , GAP ,FC LAYER AND AGAIN COMPUTES LOSS AND THIS PROCESS STOPS ONCE THE VALIDATION LOSS STOPS IMPROVING

# %% [markdown]
# ## ARGMAX

# %% [markdown]
# ### ARGMAX (argument of the maximum) is a mathematical function that returns the INDEX (position) of the largest value in a set of values — NOT the value itself, the POSITION where that value occurs.

# %% [markdown]
# ### WE RECIEVE C OUPTUT FROM THE SOFTMAX , THIS PICKS THE CLASS WHICH HAVE HIGH PROBALITY FROM THE C OUTPUT PROVIDED BY THE SOFT MAX

# %% [markdown]
# #### USUALLY WE RECIEVE THE OUPUT IN THE RANGE OF 0-1 FROM THE SOFT MAX , NOW WE PICK THE CLASS WHICH HAVE HIGH PROBALITY ACC TO SOFTMAX

# %% [markdown]
# ### THE FINAL OUTPUT IS THE CLASS WHICH HAVE HIGH PROBALITY ACC TO SOFTMAX

# %% [markdown]
# # WORKFLOW

# %% [markdown]
# ## INPUT IMAGE --> CONVOLUTION OPERATION --> ACTIVATION FUNCTION --> POOLING --> GLOBAL AVERAGED POOLING(GAP) -->FC LAYER -->SOFT MAX -->LOSS FUNCTION -->BACK_PROP ---> ARGMAX

# %% [markdown]
# ## REGULARISATION

# %% [markdown]
# ### IT IS A SET OF TECHNIQUE WHICH PREVENTS THE NEURAL NETWORK FROM THE OVERFITTING , HELPS TO IMPORVE ITS ABILITY TO GENERATE THE OUPUT ON TEH UNSEEN DATA

# %% [markdown]
# ## SAME AS THE ANN , REFER TO THAT NOTE
